# %%
a = int (input("Nhap so nguyen a = "))
b = int (input("Nhap so nguyen b ="))
print (" Tong = ", a + b)
print ( " Hieu = ", a - b)
print ( " Tich = ", a * b)
if b == 0 :
    print (" Khong the thuc hien phep chia ")
else :
     print (f" Thuong = {a/b:.3f}")
# Out:
#  Tong =  5
#  Hieu =  -1
#  Tich =  6
#  Thuong = 0.667

# %%
import math
x1 = float(input("Nhap x1 ="))
y1 = float(input("Nhap y1 ="))
x2 = float(input("Nhap x2 ="))
y2 = float(input("Nhap y2 ="))
d = math.sqrt((x1-x2)**2 + (y1-y2)**2)
print("Khoang cach d = ",d)

# %%
import math
a = int(input("Nhap a = "))
b = int(input("Nhap b = "))
c = int(input("Nhap c = "))
if a == 0:
    print ( " Khong phai PT bac 2 ")
else:
    delta = b ** 2 - 4*a*c
    if delta > 0 :
        x1 = (-b + math.sqrt(delta))
        x2 = (-b - math.sqrt(delta))
        print ( " PT co hai nghiem x1, x2 lan luot la ", x1 ,x2)
    elif delta == 0 :
        x = -b / 2*a
        print (" PT co nghiem kep x = ",x)
    else :
        print (" PT vo nghiem ")
# Out:
# 5

# %%
import math
n = int(input(" Nhap so nguyen n thuoc [20;30] = "))
while n < 20 or n > 30 :
    n = int(input("Nhap lai n = "))
x = float(input("Nhap so thuc x = "))
P = 0
for i in range (1,n+1):
    P = 2022 * x ** i + i / x ** i
print ("P = ",P)

# %%
import math
n = int(input("Nhap so nguyen duong n = "))
while n <= 0 :
    n = int(input(" Nhap lai n = "))
if n < 2:
    print ( "Khong phai la so nguyen to")
else :
    nguyenTo = True 
    for i in range (2,int(math.sqrt(n)+1)):
        if n % i == 0:
            nguyenTo = False
            break
    if nguyenTo :
        print (n," la so nguyen to")
    else :
        print (n," khong la so nguyen to")

# %%
n = int(input("Nhap so nguyen n thuoc [100;200] "))
while n < 100 or n > 200 :
     n = int(input("Nhap lai n = "))
a = 1
while a <= n:
     a *= 2
print ( "So can tim la ",a )
